# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
low_memory=False
df = pd.read_csv(r"C:\Users\14082\Desktop\db project\output\final.csv", low_memory=False) #extracted dataset

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC   AREA  \
# 0      DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA
# 1  001307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 2  011401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM      0045     14
# 3  070309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 4  090631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM      0150     06
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0  AREA NAME  Rpt Dist No  Part 1-2  Crm Cd
# 1     Newton         1385         2     900
# 2    Pacific         1485         2     740
# 3     Newton         1324         2     946
# 4  Hollywood         0646         2     900
#
#                                          Crm Cd Desc         Mocodes  \
# 0                                        Crm Cd Desc         Mocodes
# 1                           VIOLATION OF COURT ORDER  0913 1814 2000
# ...

# %%
df = df.drop(df.index[0])

# %%
df.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC TIME OCC AREA  \
# 1  001307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM     1350   13
# 2  011401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM     0045   14
# 3  070309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM     1515   13
# 4  090631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM     0150   06
# 5  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM     2100   01
#
#    AREA NAME Rpt Dist No Part 1-2 Crm Cd  \
# 1     Newton        1385        2    900
# 2    Pacific        1485        2    740
# 3     Newton        1324        2    946
# 4  Hollywood        0646        2    900
# 5    Central        0176        1    122
#
#                                          Crm Cd Desc         Mocodes Vict Age  \
# 1                           VIOLATION OF COURT ORDER  0913 1814 2000       48
# 2  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...            0329        0
# ...

# %%
df.tail()
# Out:
#              DR_NO               Date Rptd                DATE OCC TIME OCC  \
# 2458303  211208872  03/19/2021 12:00:00 AM  03/19/2021 12:00:00 AM     1105
# 2458304  210506531  03/04/2021 12:00:00 AM  03/04/2021 12:00:00 AM     2210
# 2458305  210217231  11/06/2021 12:00:00 AM  11/05/2021 12:00:00 AM     2300
# 2458306  210312887  07/12/2021 12:00:00 AM  07/12/2021 12:00:00 AM     1200
# 2458307  212005847  02/22/2021 12:00:00 AM  02/22/2021 12:00:00 AM     1200
#
#         AREA    AREA NAME Rpt Dist No Part 1-2 Crm Cd         Crm Cd Desc  \
# 2458303   12  77th Street        1218        1    510    VEHICLE - STOLEN
# 2458304    5       Harbor         564        2    434  FALSE IMPRISONMENT
# 2458305    2      Rampart         235        1    510    VEHICLE - STOLEN
# 2458306    3    Southwest         363        1    350       THEFT, PERSON
# 2458307   20      Olympic        2034        1    510    VEHICLE - STOLEN
#
# ...

# %%
df.shape # to view the dimensions(rows*cols) of the dataframe
# Out:
# (2458308, 28)

# %%
df.columns.tolist() #to view all column names
print (df.dtypes)
# Out:
# DR_NO             object
# Date Rptd         object
# DATE OCC          object
# TIME OCC          object
# AREA              object
# AREA NAME         object
# Rpt Dist No       object
# Part 1-2          object
# Crm Cd            object
# Crm Cd Desc       object
# Mocodes           object
# Vict Age          object
# Vict Sex          object
# Vict Descent      object
# Premis Cd         object
# Premis Desc       object
# Weapon Used Cd    object
# Weapon Desc       object
# Status            object
# Status Desc       object
# Crm Cd 1          object
# Crm Cd 2          object
# Crm Cd 3          object
# Crm Cd 4          object
# LOCATION          object
# Cross Street      object
# LAT               object
# LON               object
# dtype: object

# %% [markdown]
# # Explore each column of the dataset and explore the type of data stored.

# %%
#EDA on col1 (AREA)
df['AREA'] = pd.to_numeric(df['AREA'],errors = 'coerce')
df['AREA'].value_counts()
# Out:
# 12.0    170972
# 3.0     155582
# 14.0    134367
# 15.0    130963
# 18.0    128285
# 1.0     120297
# 6.0     119014
# 13.0    118406
# 11.0    115948
# 21.0    115806
# 9.0     115342
# 19.0    109091
# 17.0    108905
# 5.0     108136
# 20.0    106305
# 2.0     106170
# 8.0     106068
# 7.0     105499
# 10.0     99162
# 4.0      92305
# 16.0     91683
# Name: AREA, dtype: int64

# %%
sns.boxplot(y=df['AREA'])
plt.show()

# %%
count_nan = df['AREA'].isna().sum()
print('count:', count_nan)
# Out:
# count: 2

# %%
df['AREA'].describe()
# Out:
# count    2.458306e+06
# mean     1.098734e+01
# std      6.010253e+00
# min      1.000000e+00
# 25%      6.000000e+00
# 50%      1.100000e+01
# 75%      1.600000e+01
# max      2.100000e+01
# Name: AREA, dtype: float64

# %%
#EDA on col2 (AREA NAME)
df['AREA NAME'].value_counts()
# Out:
# 77th Street    170972
# Southwest      155582
# Pacific        134367
# N Hollywood    130963
# Southeast      128285
# Central        120297
# Hollywood      119014
# Newton         118406
# Northeast      115948
# Topanga        115806
# Van Nuys       115342
# Mission        109091
# Devonshire     108905
# Harbor         108136
# Olympic        106305
# Rampart        106170
# West LA        106068
# Wilshire       105499
# West Valley     99162
# Hollenbeck      92305
# Foothill        91683
# AREA NAME           2
# Name: AREA NAME, dtype: int64

# %%
#print(df['AREA NAME'].where(df['AREA NAME'] == 'AREA NAME'))
if 'AREA NAME' in df.values:
    print('Element exists in Dataframe')
else:
    print('Element does not exist')
# Out:
# Element exists in Dataframe

# %%
count_nan = df['AREA NAME'].isna().sum()
print('count:', count_nan)
# Out:
# count: 0

# %%
#EDA on col2 (Rpt Dist No)
pd.set_option('display.max_rows', None)
df['Rpt Dist No'] = pd.to_numeric(df['Rpt Dist No'],errors = 'coerce')
df['Rpt Dist No'].value_counts()
# Out:
# 645.0     12783
# 363.0     11407
# 646.0     10915
# 2156.0    10351
# 636.0      9846
# 1494.0     9826
# 162.0      8375
# 1822.0     8298
# 1239.0     8022
# 666.0      7355
# 1764.0     7300
# 1801.0     7268
# 1269.0     7182
# 111.0      7085
# 1802.0     6898
# 1842.0     6807
# 1985.0     6742
# 152.0      6619
# 1241.0     6606
# 1268.0     6503
# 1258.0     6452
# 1431.0     6434
# 397.0      6331
# 1245.0     6187
# 1555.0     6143
# 1259.0     6109
# 647.0      6051
# 923.0      6037
# 1267.0     6009
# 1265.0     5988
# 362.0      5857
# 563.0      5847
# 964.0      5833
# 1844.0     5772
# 1243.0     5657
# 395.0      5636
# 245.0      5606
# 182.0      5601
# 914.0      5597
# 153.0      5563
# 1824.0     5551
# 721.0      5548
# 156.0      5466
# 1266.0     5459
# 1273.0     5444
# 1548.0     5427
# 2029.0     5398
# 2157.0     5377
# 1823.0     5376
# 1249.0     5368
# 765.0      5364
# 393.0      5348
# 1488.0     5334
# 1256.0     5304
# 1203.0     5303
# ...

# %%
#EDA on col3 (Rpt Dist No)
df_count = df['Rpt Dist No'].value_counts()
df_count.value_counts().head()
# Out:
# 1    53
# 2    35
# 3    23
# 4    17
# 5     9
# Name: Rpt Dist No, dtype: int64

# %%
sns.boxplot(y=df['Rpt Dist No'])
plt.show()

# %%
count_nan = df['Rpt Dist No'].isna().sum()
print('count:', count_nan)
# Out:
# count: 2

# %%
df['Rpt Dist No'].describe()
# Out:
# count    2.458306e+06
# mean     1.145098e+03
# std      6.010379e+02
# min      1.000000e+02
# 25%      6.380000e+02
# 50%      1.176000e+03
# 75%      1.653000e+03
# max      2.199000e+03
# Name: Rpt Dist No, dtype: float64

# %%
#EDA on col4  (Crm Cd)
pd.set_option('display.max_rows', None)
df['Crm Cd'] = pd.to_numeric(df['Crm Cd'],errors = 'coerce')
df_count1 = df['Crm Cd'].value_counts().sort_values(ascending=True)
print(df_count1)
# Out:
# 225.0         1
# 953.0         1
# 1784.0        1
# 1671.0        1
# 768.0         1
# 771.0         1
# 277.0         1
# 693.0         1
# 200.0         1
# 254.0         1
# 223.0         1
# 1051.0        1
# 699.0         1
# 224.0         1
# 604.0         1
# 797.0         1
# 794.0         1
# 1046.0        1
# 951.0         1
# 708.0         1
# 1072.0        1
# 973.0         1
# 977.0         1
# 718.0         1
# 1786.0        1
# 967.0         1
# 972.0         1
# 988.0         1
# 400.0         1
# 1627.0        1
# 1733.0        1
# 1014.0        1
# 1997.0        1
# 1093.0        1
# 1057.0        1
# 922.0         1
# 968.0         1
# 1536.0        1
# 1706.0        1
# 1928.0        1
# 228.0         1
# 1537.0        1
# 1059.0        1
# 1731.0        1
# 1726.0        1
# 1652.0        1
# 1927.0        1
# 1552.0        1
# 798.0         1
# 792.0         1
# 232.0         1
# 1724.0        1
# 1085.0        1
# 928.0         2
# 226.0         2
# ...

# %%
df_count1.value_counts().head(8)
# Out:
# 1       53
# 2       35
# 3       23
# 4       17
# 5        9
# 6        6
# 2441     3
# 721      3
# Name: Crm Cd, dtype: int64

# %%
count_nan = df['Crm Cd'].isna().sum()
print('count:', count_nan)
# Out:
# count: 2

# %%
#boxplot

# %%
#EDA on col5  (Crm Cd Desc)
pd.set_option('display.max_rows', None)

df_count2 = df['Crm Cd Desc'].value_counts().sort_values(ascending=True)
print(df_count2)
# Out:
# FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)               1
# DRUNK ROLL - ATTEMPT                                             1
# Crm Cd Desc                                                      2
# TRAIN WRECKING                                                   2
# TILL TAP - ATTEMPT                                               3
# FIREARMS RESTRAINING ORDER (FIREARMS RO)                         3
# BLOCKING DOOR INDUCTION CENTER                                   4
# ABORTION/ILLEGAL                                                 7
# DISHONEST EMPLOYEE ATTEMPTED THEFT                              10
# MANSLAUGHTER, NEGLIGENT                                         10
# INCITING A RIOT                                                 11
# GRAND THEFT / AUTO REPAIR                                       12
# BIGAMY                                                          15
# INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)                    15
# ...

# %%
count_nan = df['Crm Cd Desc'].isna().sum()
print('count:', count_nan)
# Out:
# count: 0

# %%
#EDA on col6  (Mocodes)
pd.set_option('display.max_rows', None)

count_nan = df['Mocodes'].isna().sum()
print('count:', count_nan)
# Out:
# count: 278395

# %%
#EDA on col7 (Vict Age)
pd.set_option('display.max_rows', None)
df['Vict Age'] = pd.to_numeric(df['Vict Age'],errors = 'coerce')
df['Vict Age'].value_counts().sort_values(ascending=True)
# Out:
#  120.0         1
#  118.0         1
# -11.0          1
#  114.0         2
# -10.0          2
# -9.0           9
# -8.0           9
# -7.0          16
# -6.0          18
# -5.0          21
# -4.0          43
# -3.0          69
# -2.0         122
#  98.0        158
#  97.0        208
#  96.0        209
# -1.0         272
#  95.0        285
#  94.0        361
#  93.0        461
#  92.0        546
#  91.0        712
#  90.0        845
#  99.0        930
#  89.0        997
#  88.0       1183
#  87.0       1306
#  2.0        1588
#  86.0       1589
#  85.0       1722
#  84.0       1950
#  3.0        1986
#  83.0       2205
#  4.0        2338
#  82.0       2397
#  5.0        2624
#  6.0        2663
#  81.0       2713
#  7.0        2734
#  8.0        2887
#  80.0       3038
#  79.0       3350
#  9.0        3596
#  78.0       3726
#  77.0       4094
#  10.0       4101
#  76.0       4380
#  75.0       4970
#  74.0       5317
#  11.0       5653
#  73.0       5838
#  72.0       6817
# ...

# %%
sns.boxplot(y=df['Vict Age'])
plt.show()

# %%
count_nan = df['Vict Age'].isna().sum()
print('count:', count_nan)
# Out:
# count: 2

# %%
df['Vict Age'].describe()

# %%
#EDA on col7 (Vict Sex)
pd.set_option('display.max_rows', None)
df['Vict Sex'].value_counts().sort_values(ascending=True)
# Out:
# -                 1
# Vict Sex          1
# N                22
# H               118
# X             86781
# F           1008354
# M           1117324
# Name: Vict Sex, dtype: int64

# %%
count_nan1 = df['Vict Sex'].isna().sum()
print('count:', count_nan1)
# Out:
# count: 245706

# %%
#EDA on col7 (Status)
count_nan2 = df['Status'].isna().sum()
print('count:', count_nan2)
# Out:
# count: 2

# %%
#EDA on col7 (Status Desc)
count_nan3 = df['Status Desc'].isna().sum()
print('count:', count_nan3)
# Out:
# count: 0

# %%
#EDA on col7 (Crm Cd 1)
count_nan4 = df['Crm Cd 1'].isna().sum()
print('count:', count_nan4)
# Out:
# count: 13

# %%
#EDA on col7 (Premis Cd)
count_nan5 = df['Premis Cd'].isna().sum()
print('count:', count_nan5)
# Out:
# count: 58

# %%
#EDA on col7 (Premis Desc)
count_nan6 = df['Premis Desc'].isna().sum()
print('count:', count_nan6)
# Out:
# count: 304

# %%
#EDA on col7 (Weapon Used Cd)
count_nan7 = df['Weapon Used Cd'].isna().sum()
print('count:', count_nan7)
# Out:
# count: 1617408

# %%
#EDA on col7 (Weapon Desc)
count_nan8 = df['Weapon Desc'].isna().sum()
print('count:', count_nan8)
# Out:
# count: 1617409

# %%
df.to_csv(r'C:\Users\14082\Desktop\db project\output\crime_analysis.csv', index = False, header=True)
df.withColumn('address', 
    when(df.address.endswith('Rd'),regexp_replace(df.address,'Rd','Road')) \
   .when(df.address.endswith('St'),regexp_replace(df.address,'St','Street')) \
   .when(df.address.endswith('Ave'),regexp_replace(df.address,'Ave','Avenue')) \
   .otherwise(df.address)) \
   .show(truncate=False)

# %%
cust_df = df.withColumn("vict_sex", when(df["vict_sex"] == 'H', 'X').when(df["vict_sex"] == '-', 'X').when(df["vict_sex"] == 'N', 'X').otherwise(df["vict_sex"]).when(df["vict_sex"] == 'Vict Sex', 'X').otherwise(df["vict_sex"]).show(truncate=False))

# %%
df = df.withColumn("vict_sex", when(df.vict_sex == "H","X")
                                 .when(df.vict_sex == "-","X")
                                 .when(df.vict_sex == "N" ,"")
                                 .otherwise(df.vict_sex))
